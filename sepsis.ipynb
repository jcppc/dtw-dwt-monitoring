# %% [markdown]
# # <img align='right' src='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0dFut9RjhIwwK1LBIlU3h045PTD_tdwc6SA&s'>
# ## <font color='darkseagreen'> **Time-Driven Bucketing and Wavelet Encoding for Process Prediction**</font>
# ### <font color='black'> **Sepsis Notebook**</font>
# #### <font color='grey'> *Diogo Silva & João Caldeira @ 2026*</font>
# <b>dtw-dwt-monitoring</b> is a framework for predictive process monitoring and time-series analytics that combines Dynamic Time Warping (DTW) and Discrete Wavelet Transform (DWT) techniques for advanced feature extraction and similarity analysis.<p>
# <hr>

# %% [markdown]
# # Full Pipeline

# %%
# Just to check Python version
# !python --version
# Out:
# Python 3.10.9

# %%
# Install your packages using pip and the requirements.txt file
# !python -m pip install -r requirements.txt

# %%
# Read the data
import pandas as pd
sepsis = pd.read_parquet('inputs/sepsis.parquet')
